# %% [markdown]
# # 1. [Opt] Check GPU Type

# %%
# Check GPU Type
gpu_info = !system_profiler SPDisplaysDataType
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Graphics/Displays:
#
#     Apple M1:
#
#       Chipset Model: Apple M1
#       Type: GPU
#       Bus: Built-In
#       Total Number of Cores: 8
#       Vendor: Apple (0x106b)
#       Metal Family: Supported, Metal GPUFamily Apple 7
#       Displays:
#         Color LCD:
#           Resolution: 2880 x 1800
#           UI Looks like: 1440 x 900 @ 60.00Hz
#           Main Display: Yes
#           Mirror: Off
#           Online: Yes
#           Automatically Adjust Brightness: No
#           Connection Type: Internal

# %% [markdown]
# # 2. Git Clone from Github Repository to root directory
# At Colab, location is "/content/".
#
# Using `$ git clone https://github.com/lainyzine/git-clone.git` will load the Github repository with the name of the repository. With Colab, it can be convenient to work in the root directory. You can use the command to call the root directory as shown below.
#
# According to the Github repository, we can use `! git pull origin main` or `! Just use git pull origin master`.

# %%
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_32_Pytorch_Complex_Yolo_Yolov4.git
# ! git pull origin master
! git pull origin main
# Out:
# Reinitialized existing Git repository in /Users/lintsao/Desktop/UCSD/ECE 285/UCSD-ECE-285-Final-Project-3D-Object-Detection/.git/
# error: remote origin already exists.
# hint: Pulling without specifying how to reconcile divergent branches is
# hint: discouraged. You can squelch this message by running one of the following
# hint: commands sometime before your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# From https://github.com/lintsao/UCSD-ECE-285-Final-Project-3D-Object-Detection
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# # 3. import clear_output

# %%
from IPython.display import clear_output 
clear_output()

# %% [markdown]
# # 4. Kitti dataset download from Auther's Github repository

# %%
# !pip install --upgrade --no-cache-dir gdown

# Due to the size of data it was separated with two files
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz'
output_name = 'Complex-YOLOv4_Data_1.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz/view?usp=sharing

# Due to the size of data it was separated with two files
google_path = 'https://drive.google.com/uc?id='
file_id = '1_WIldJYOrxmVVSjm0no10Llg8vi3VstE'
output_name = 'Complex-YOLOv4_Data_2.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1_WIldJYOrxmVVSjm0no10Llg8vi3VstE/view?usp=sharing

# !unzip -o /content/Complex-YOLOv4_Data_1.zip -d /content/
clear_output()
# !rm /content/Complex-YOLOv4_Data_1.zip

# !unzip -o /content/Complex-YOLOv4_Data_2.zip -d /content/
clear_output()
# !rm /content/Complex-YOLOv4_Data_2.zip
# Out:
# Archive:  Complex-YOLOv4_Data_2.zip
#   inflating: dataset/kitti/training/velodyne/000000.bin
#   inflating: dataset/kitti/training/velodyne/000001.bin
#   inflating: dataset/kitti/training/velodyne/000002.bin
#   inflating: dataset/kitti/training/velodyne/000003.bin
#   inflating: dataset/kitti/training/velodyne/000004.bin
#   inflating: dataset/kitti/training/velodyne/000005.bin
#   inflating: dataset/kitti/training/velodyne/000006.bin
#   inflating: dataset/kitti/training/velodyne/000007.bin
#   inflating: dataset/kitti/training/velodyne/000008.bin
#   inflating: dataset/kitti/training/velodyne/000009.bin
#   inflating: dataset/kitti/training/velodyne/000010.bin
#   inflating: dataset/kitti/training/velodyne/000011.bin
#   inflating: dataset/kitti/training/velodyne/000012.bin
#   inflating: dataset/kitti/training/velodyne/000013.bin
#   inflating: dataset/kitti/training/velodyne/000014.bin
#   inflating: dataset/kitti/training/velodyne/000015.bin
#   inflating: dataset/kitti/training/velodyne/000016.bin
#   inflating: dataset/kitti/training/velodyne/000017.bin
#   inflating: dataset/kitti/training/velodyne/000018.bin
#   inflating: dataset/kitti/training/velodyne/000019.bin
#   inflating: dataset/kitti/training/velodyne/000020.bin
#   inflating: dataset/kitti/training/velodyne/000021.bin
#   inflating: dataset/kitti/training/velodyne/000022.bin
#   inflating: dataset/kitti/training/velodyne/000023.bin
#   inflating: dataset/kitti/training/velodyne/000024.bin
#   inflating: dataset/kitti/training/velodyne/000025.bin
#   inflating: dataset/kitti/training/velodyne/000026.bin
#   inflating: dataset/kitti/training/velodyne/000027.bin
#   inflating: dataset/kitti/training/velodyne/000028.bin
#   inflating: dataset/kitti/training/velodyne/000029.bin
#   inflating: dataset/kitti/training/velodyne/000030.bin
#   inflating: dataset/kitti/training/velodyne/000031.bin
#   inflating: dataset/kitti/training/velodyne/000032.bin
#   inflating: dataset/kitti/training/velodyne/000033.bin
#   inflating: dataset/kitti/training/velodyne/000034.bin
#   inflating: dataset/kitti/training/velodyne/000035.bin
#   inflating: dataset/kitti/training/velodyne/000036.bin
#   inflating: dataset/kitti/training/velodyne/000037.bin
#   inflating: dataset/kitti/training/velodyne/000038.bin
#   inflating: dataset/kitti/training/velodyne/000039.bin
#   inflating: dataset/kitti/training/velodyne/000040.bin
#   inflating: dataset/kitti/training/velodyne/000041.bin
#   inflating: dataset/kitti/training/velodyne/000042.bin
#   inflating: dataset/kitti/training/velodyne/000043.bin
#   inflating: dataset/kitti/training/velodyne/000044.bin
#   inflating: dataset/kitti/training/velodyne/000045.bin
#   inflating: dataset/kitti/training/velodyne/000046.bin
#   inflating: dataset/kitti/training/velodyne/000047.bin
#   inflating: dataset/kitti/training/velodyne/000048.bin
#   inflating: dataset/kitti/training/velodyne/000049.bin
#   inflating: dataset/kitti/training/velodyne/000050.bin
#   inflating: dataset/kitti/training/velodyne/000051.bin
#   inflating: dataset/kitti/training/velodyne/000052.bin
#   inflating: dataset/kitti/training/velodyne/000053.bin
#   inflating: dataset/kitti/training/velodyne/000054.bin
#   inflating: dataset/kitti/training/velodyne/000055.bin
#   inflating: dataset/kitti/training/velodyne/000056.bin
#   inflating: dataset/kitti/training/velodyne/000057.bin
#   inflating: dataset/kitti/training/velodyne/000058.bin
#   inflating: dataset/kitti/training/velodyne/000059.bin
#   inflating: dataset/kitti/training/velodyne/000060.bin
#   inflating: dataset/kitti/training/velodyne/000061.bin
#   inflating: dataset/kitti/training/velodyne/000062.bin
#   inflating: dataset/kitti/training/velodyne/000063.bin
#   inflating: dataset/kitti/training/velodyne/000064.bin
#   inflating: dataset/kitti/training/velodyne/000065.bin
#   inflating: dataset/kitti/training/velodyne/000066.bin
#   inflating: dataset/kitti/training/velodyne/000067.bin
#   inflating: dataset/kitti/training/velodyne/000068.bin
#   inflating: dataset/kitti/training/velodyne/000069.bin
#   inflating: dataset/kitti/training/velodyne/000070.bin
#   inflating: dataset/kitti/training/velodyne/000071.bin
#   inflating: dataset/kitti/training/velodyne/000072.bin
#   inflating: dataset/kitti/training/velodyne/000073.bin
#   inflating: dataset/kitti/training/velodyne/000074.bin
#   inflating: dataset/kitti/training/velodyne/000075.bin
#   inflating: dataset/kitti/training/velodyne/000076.bin
#   inflating: dataset/kitti/training/velodyne/000077.bin
#   inflating: dataset/kitti/training/velodyne/000078.bin
#   inflating: dataset/kitti/training/velodyne/000079.bin
#   inflating: dataset/kitti/training/velodyne/000080.bin
#   inflating: dataset/kitti/training/velodyne/000081.bin
#   inflating: dataset/kitti/training/velodyne/000082.bin
#   inflating: dataset/kitti/training/velodyne/000083.bin
#   inflating: dataset/kitti/training/velodyne/000084.bin
#   inflating: dataset/kitti/training/velodyne/000085.bin
#   inflating: dataset/kitti/training/velodyne/000086.bin
#   inflating: dataset/kitti/training/velodyne/000087.bin
#   inflating: dataset/kitti/training/velodyne/000088.bin
#   inflating: dataset/kitti/training/velodyne/000089.bin
#   inflating: dataset/kitti/training/velodyne/000090.bin
#   inflating: dataset/kitti/training/velodyne/000091.bin
#   inflating: dataset/kitti/training/velodyne/000092.bin
#   inflating: dataset/kitti/training/velodyne/000093.bin
#   inflating: dataset/kitti/training/velodyne/000094.bin
#   inflating: dataset/kitti/training/velodyne/000095.bin
#   inflating: dataset/kitti/training/velodyne/000096.bin
#   inflating: dataset/kitti/training/velodyne/000097.bin
#   inflating: dataset/kitti/training/velodyne/000098.bin
#   inflating: dataset/kitti/training/velodyne/000099.bin
#   inflating: dataset/kitti/training/velodyne/000100.bin
#   inflating: dataset/kitti/training/velodyne/000101.bin
#   inflating: dataset/kitti/training/velodyne/000102.bin
#   inflating: dataset/kitti/training/velodyne/000103.bin
#   inflating: dataset/kitti/training/velodyne/000104.bin
#   inflating: dataset/kitti/training/velodyne/000105.bin
#   inflating: dataset/kitti/training/velodyne/000106.bin
#   inflating: dataset/kitti/training/velodyne/000107.bin
#   inflating: dataset/kitti/training/velodyne/000108.bin
#   inflating: dataset/kitti/training/velodyne/000109.bin
#   inflating: dataset/kitti/training/velodyne/000110.bin
#   inflating: dataset/kitti/training/velodyne/000111.bin
#   inflating: dataset/kitti/training/velodyne/000112.bin
#   inflating: dataset/kitti/training/velodyne/000113.bin
#   inflating: dataset/kitti/training/velodyne/000114.bin
#   inflating: dataset/kitti/training/velodyne/000115.bin
#   inflating: dataset/kitti/training/velodyne/000116.bin
#   inflating: dataset/kitti/training/velodyne/000117.bin
#   inflating: dataset/kitti/training/velodyne/000118.bin
#   inflating: dataset/kitti/training/velodyne/000119.bin
#   inflating: dataset/kitti/training/velodyne/000120.bin
#   inflating: dataset/kitti/training/velodyne/000121.bin
#   inflating: dataset/kitti/training/velodyne/000122.bin
#   inflating: dataset/kitti/training/velodyne/000123.bin
#   inflating: dataset/kitti/training/velodyne/000124.bin
#   inflating: dataset/kitti/training/velodyne/000125.bin
#   inflating: dataset/kitti/training/velodyne/000126.bin
#   inflating: dataset/kitti/training/velodyne/000127.bin
#   inflating: dataset/kitti/training/velodyne/000128.bin
#   inflating: dataset/kitti/training/velodyne/000129.bin
#   inflating: dataset/kitti/training/velodyne/000130.bin
#   inflating: dataset/kitti/training/velodyne/000131.bin
#   inflating: dataset/kitti/training/velodyne/000132.bin
#   inflating: dataset/kitti/training/velodyne/000133.bin
#   inflating: dataset/kitti/training/velodyne/000134.bin
#   inflating: dataset/kitti/training/velodyne/000135.bin
#   inflating: dataset/kitti/training/velodyne/000136.bin
#   inflating: dataset/kitti/training/velodyne/000137.bin
#   inflating: dataset/kitti/training/velodyne/000138.bin
#   inflating: dataset/kitti/training/velodyne/000139.bin
#   inflating: dataset/kitti/training/velodyne/000140.bin
#   inflating: dataset/kitti/training/velodyne/000141.bin
#   inflating: dataset/kitti/training/velodyne/000142.bin
#   inflating: dataset/kitti/training/velodyne/000143.bin
#   inflating: dataset/kitti/training/velodyne/000144.bin
#   inflating: dataset/kitti/training/velodyne/000145.bin
#   inflating: dataset/kitti/training/velodyne/000146.bin
#   inflating: dataset/kitti/training/velodyne/000147.bin
#   inflating: dataset/kitti/training/velodyne/000148.bin
#   inflating: dataset/kitti/training/velodyne/000149.bin
#   inflating: dataset/kitti/training/velodyne/000150.bin
#   inflating: dataset/kitti/training/velodyne/000151.bin
#   inflating: dataset/kitti/training/velodyne/000152.bin
#   inflating: dataset/kitti/training/velodyne/000153.bin
#   inflating: dataset/kitti/training/velodyne/000154.bin
#   inflating: dataset/kitti/training/velodyne/000155.bin
#   inflating: dataset/kitti/training/velodyne/000156.bin
#   inflating: dataset/kitti/training/velodyne/000157.bin
#   inflating: dataset/kitti/training/velodyne/000158.bin
#   inflating: dataset/kitti/training/velodyne/000159.bin
#   inflating: dataset/kitti/training/velodyne/000160.bin
#   inflating: dataset/kitti/training/velodyne/000161.bin
#   inflating: dataset/kitti/training/velodyne/000162.bin
#   inflating: dataset/kitti/training/velodyne/000163.bin
#   inflating: dataset/kitti/training/velodyne/000164.bin
#   inflating: dataset/kitti/training/velodyne/000165.bin
#   inflating: dataset/kitti/training/velodyne/000166.bin
#   inflating: dataset/kitti/training/velodyne/000167.bin
#   inflating: dataset/kitti/training/velodyne/000168.bin
#   inflating: dataset/kitti/training/velodyne/000169.bin
#   inflating: dataset/kitti/training/velodyne/000170.bin
#   inflating: dataset/kitti/training/velodyne/000171.bin
#   inflating: dataset/kitti/training/velodyne/000172.bin
#   inflating: dataset/kitti/training/velodyne/000173.bin
#   inflating: dataset/kitti/training/velodyne/000174.bin
#   inflating: dataset/kitti/training/velodyne/000175.bin
#   inflating: dataset/kitti/training/velodyne/000176.bin
#   inflating: dataset/kitti/training/velodyne/000177.bin
#   inflating: dataset/kitti/training/velodyne/000178.bin
#   inflating: dataset/kitti/training/velodyne/000179.bin
#   inflating: dataset/kitti/training/velodyne/000180.bin
#   inflating: dataset/kitti/training/velodyne/000181.bin
#   inflating: dataset/kitti/training/velodyne/000182.bin
#   inflating: dataset/kitti/training/velodyne/000183.bin
#   inflating: dataset/kitti/training/velodyne/000184.bin
#   inflating: dataset/kitti/training/velodyne/000185.bin
#   inflating: dataset/kitti/training/velodyne/000186.bin
#   inflating: dataset/kitti/training/velodyne/000187.bin
#   inflating: dataset/kitti/training/velodyne/000188.bin
#   inflating: dataset/kitti/training/velodyne/000189.bin
#   inflating: dataset/kitti/training/velodyne/000190.bin
#   inflating: dataset/kitti/training/velodyne/000191.bin
#   inflating: dataset/kitti/training/velodyne/000192.bin
#   inflating: dataset/kitti/training/velodyne/000193.bin
#   inflating: dataset/kitti/training/velodyne/000194.bin
#   inflating: dataset/kitti/training/velodyne/000195.bin
#   inflating: dataset/kitti/training/velodyne/000196.bin
#   inflating: dataset/kitti/training/velodyne/000197.bin
#   inflating: dataset/kitti/training/velodyne/000198.bin
#   inflating: dataset/kitti/training/velodyne/000199.bin
#   inflating: dataset/kitti/training/velodyne/000200.bin
#   inflating: dataset/kitti/training/velodyne/000201.bin
#   inflating: dataset/kitti/training/velodyne/000202.bin
#   inflating: dataset/kitti/training/velodyne/000203.bin
#   inflating: dataset/kitti/training/velodyne/000204.bin
#   inflating: dataset/kitti/training/velodyne/000205.bin
#   inflating: dataset/kitti/training/velodyne/000206.bin
#   inflating: dataset/kitti/training/velodyne/000207.bin
#   inflating: dataset/kitti/training/velodyne/000208.bin
#   inflating: dataset/kitti/training/velodyne/000209.bin
#   inflating: dataset/kitti/training/velodyne/000210.bin
#   inflating: dataset/kitti/training/velodyne/000211.bin
#   inflating: dataset/kitti/training/velodyne/000212.bin
#   inflating: dataset/kitti/training/velodyne/000213.bin
#   inflating: dataset/kitti/training/velodyne/000214.bin
#   inflating: dataset/kitti/training/velodyne/000215.bin
#   inflating: dataset/kitti/training/velodyne/000216.bin
#   inflating: dataset/kitti/training/velodyne/000217.bin
#   inflating: dataset/kitti/training/velodyne/000218.bin
#   inflating: dataset/kitti/training/velodyne/000219.bin
#   inflating: dataset/kitti/training/velodyne/000220.bin
#   inflating: dataset/kitti/training/velodyne/000221.bin
#   inflating: dataset/kitti/training/velodyne/000222.bin
#   inflating: dataset/kitti/training/velodyne/000223.bin
#   inflating: dataset/kitti/training/velodyne/000224.bin
#   inflating: dataset/kitti/training/velodyne/000225.bin
#   inflating: dataset/kitti/training/velodyne/000226.bin
#   inflating: dataset/kitti/training/velodyne/000227.bin
#   inflating: dataset/kitti/training/velodyne/000228.bin
#   inflating: dataset/kitti/training/velodyne/000229.bin
#   inflating: dataset/kitti/training/velodyne/000230.bin
#   inflating: dataset/kitti/training/velodyne/000231.bin
#   inflating: dataset/kitti/training/velodyne/000232.bin
#   inflating: dataset/kitti/training/velodyne/000233.bin
#   inflating: dataset/kitti/training/velodyne/000234.bin
#   inflating: dataset/kitti/training/velodyne/000235.bin
#   inflating: dataset/kitti/training/velodyne/000236.bin
#   inflating: dataset/kitti/training/velodyne/000237.bin
#   inflating: dataset/kitti/training/velodyne/000238.bin
#   inflating: dataset/kitti/training/velodyne/000239.bin
#   inflating: dataset/kitti/training/velodyne/000240.bin
#   inflating: dataset/kitti/training/velodyne/000241.bin
#   inflating: dataset/kitti/training/velodyne/000242.bin
#   inflating: dataset/kitti/training/velodyne/000243.bin
#   inflating: dataset/kitti/training/velodyne/000244.bin
#   inflating: dataset/kitti/training/velodyne/000245.bin
#   inflating: dataset/kitti/training/velodyne/000246.bin
#   inflating: dataset/kitti/training/velodyne/000247.bin
#   inflating: dataset/kitti/training/velodyne/000248.bin
#   inflating: dataset/kitti/training/velodyne/000249.bin
#   inflating: dataset/kitti/training/velodyne/000250.bin
#   inflating: dataset/kitti/training/velodyne/000251.bin
#   inflating: dataset/kitti/training/velodyne/000252.bin
#   inflating: dataset/kitti/training/velodyne/000253.bin
#   inflating: dataset/kitti/training/velodyne/000254.bin
#   inflating: dataset/kitti/training/velodyne/000255.bin
#   inflating: dataset/kitti/training/velodyne/000256.bin
#   inflating: dataset/kitti/training/velodyne/000257.bin
#   inflating: dataset/kitti/training/velodyne/000258.bin
#   inflating: dataset/kitti/training/velodyne/000259.bin
#   inflating: dataset/kitti/training/velodyne/000260.bin
#   inflating: dataset/kitti/training/velodyne/000261.bin
#   inflating: dataset/kitti/training/velodyne/000262.bin
#   inflating: dataset/kitti/training/velodyne/000263.bin
#   inflating: dataset/kitti/training/velodyne/000264.bin
#   inflating: dataset/kitti/training/velodyne/000265.bin
#   inflating: dataset/kitti/training/velodyne/000266.bin
#   inflating: dataset/kitti/training/velodyne/000267.bin
#   inflating: dataset/kitti/training/velodyne/000268.bin
#   inflating: dataset/kitti/training/velodyne/000269.bin
#   inflating: dataset/kitti/training/velodyne/000270.bin
#   inflating: dataset/kitti/training/velodyne/000271.bin
#   inflating: dataset/kitti/training/velodyne/000272.bin
#   inflating: dataset/kitti/training/velodyne/000273.bin
#   inflating: dataset/kitti/training/velodyne/000274.bin
#   inflating: dataset/kitti/training/velodyne/000275.bin
#   inflating: dataset/kitti/training/velodyne/000276.bin
#   inflating: dataset/kitti/training/velodyne/000277.bin
#   inflating: dataset/kitti/training/velodyne/000278.bin
#   inflating: dataset/kitti/training/velodyne/000279.bin
#   inflating: dataset/kitti/training/velodyne/000280.bin
#   inflating: dataset/kitti/training/velodyne/000281.bin
#   inflating: dataset/kitti/training/velodyne/000282.bin
#   inflating: dataset/kitti/training/velodyne/000283.bin
#   inflating: dataset/kitti/training/velodyne/000284.bin
#   inflating: dataset/kitti/training/velodyne/000285.bin
#   inflating: dataset/kitti/training/velodyne/000286.bin
#   inflating: dataset/kitti/training/velodyne/000287.bin
#   inflating: dataset/kitti/training/velodyne/000288.bin
#   inflating: dataset/kitti/training/velodyne/000289.bin
#   inflating: dataset/kitti/training/velodyne/000290.bin
#   inflating: dataset/kitti/training/velodyne/000291.bin
#   inflating: dataset/kitti/training/velodyne/000292.bin
#   inflating: dataset/kitti/training/velodyne/000293.bin
#   inflating: dataset/kitti/training/velodyne/000294.bin
#   inflating: dataset/kitti/training/velodyne/000295.bin
#   inflating: dataset/kitti/training/velodyne/000296.bin
#   inflating: dataset/kitti/training/velodyne/000297.bin
#   inflating: dataset/kitti/training/velodyne/000298.bin
#   inflating: dataset/kitti/training/velodyne/000299.bin
#   inflating: dataset/kitti/training/velodyne/000300.bin
#   inflating: dataset/kitti/training/velodyne/000301.bin
#   inflating: dataset/kitti/training/velodyne/000302.bin
#   inflating: dataset/kitti/training/velodyne/000303.bin
#   inflating: dataset/kitti/training/velodyne/000304.bin
#   inflating: dataset/kitti/training/velodyne/000305.bin
#   inflating: dataset/kitti/training/velodyne/000306.bin
#   inflating: dataset/kitti/training/velodyne/000307.bin
#   inflating: dataset/kitti/training/velodyne/000308.bin
#   inflating: dataset/kitti/training/velodyne/000309.bin
#   inflating: dataset/kitti/training/velodyne/000310.bin
#   inflating: dataset/kitti/training/velodyne/000311.bin
#   inflating: dataset/kitti/training/velodyne/000312.bin
#   inflating: dataset/kitti/training/velodyne/000313.bin
#   inflating: dataset/kitti/training/velodyne/000314.bin
#   inflating: dataset/kitti/training/velodyne/000315.bin
#   inflating: dataset/kitti/training/velodyne/000316.bin
#   inflating: dataset/kitti/training/velodyne/000317.bin
#   inflating: dataset/kitti/training/velodyne/000318.bin
#   inflating: dataset/kitti/training/velodyne/000319.bin
#   inflating: dataset/kitti/training/velodyne/000320.bin
#   inflating: dataset/kitti/training/velodyne/000321.bin
#   inflating: dataset/kitti/training/velodyne/000322.bin
#   inflating: dataset/kitti/training/velodyne/000323.bin
#   inflating: dataset/kitti/training/velodyne/000324.bin
#   inflating: dataset/kitti/training/velodyne/000325.bin
#   inflating: dataset/kitti/training/velodyne/000326.bin
#   inflating: dataset/kitti/training/velodyne/000327.bin
#   inflating: dataset/kitti/training/velodyne/000328.bin
#   inflating: dataset/kitti/training/velodyne/000329.bin
#   inflating: dataset/kitti/training/velodyne/000330.bin
#   inflating: dataset/kitti/training/velodyne/000331.bin
#   inflating: dataset/kitti/training/velodyne/000332.bin
#   inflating: dataset/kitti/training/velodyne/000333.bin
#   inflating: dataset/kitti/training/velodyne/000334.bin
#   inflating: dataset/kitti/training/velodyne/000335.bin
#   inflating: dataset/kitti/training/velodyne/000336.bin
#   inflating: dataset/kitti/training/velodyne/000337.bin
#   inflating: dataset/kitti/training/velodyne/000338.bin
#   inflating: dataset/kitti/training/velodyne/000339.bin
#   inflating: dataset/kitti/training/velodyne/000340.bin
#   inflating: dataset/kitti/training/velodyne/000341.bin
#   inflating: dataset/kitti/training/velodyne/000342.bin
#   inflating: dataset/kitti/training/velodyne/000343.bin
#   inflating: dataset/kitti/training/velodyne/000344.bin
#   inflating: dataset/kitti/training/velodyne/000345.bin
#   inflating: dataset/kitti/training/velodyne/000346.bin
#   inflating: dataset/kitti/training/velodyne/000347.bin
#   inflating: dataset/kitti/training/velodyne/000348.bin
#   inflating: dataset/kitti/training/velodyne/000349.bin
#   inflating: dataset/kitti/training/velodyne/000350.bin
#   inflating: dataset/kitti/training/velodyne/000351.bin
#   inflating: dataset/kitti/training/velodyne/000352.bin
#   inflating: dataset/kitti/training/velodyne/000353.bin
#   inflating: dataset/kitti/training/velodyne/000354.bin
#   inflating: dataset/kitti/training/velodyne/000355.bin
#   inflating: dataset/kitti/training/velodyne/000356.bin
#   inflating: dataset/kitti/training/velodyne/000357.bin
#   inflating: dataset/kitti/training/velodyne/000358.bin
#   inflating: dataset/kitti/training/velodyne/000359.bin
#   inflating: dataset/kitti/training/velodyne/000360.bin
#   inflating: dataset/kitti/training/velodyne/000361.bin
#   inflating: dataset/kitti/training/velodyne/000362.bin
#   inflating: dataset/kitti/training/velodyne/000363.bin
#   inflating: dataset/kitti/training/velodyne/000364.bin
#   inflating: dataset/kitti/training/velodyne/000365.bin
#   inflating: dataset/kitti/training/velodyne/000366.bin
#   inflating: dataset/kitti/training/velodyne/000367.bin
#   inflating: dataset/kitti/training/velodyne/000368.bin
#   inflating: dataset/kitti/training/velodyne/000369.bin
#   inflating: dataset/kitti/training/velodyne/000370.bin
#   inflating: dataset/kitti/training/velodyne/000371.bin
#   inflating: dataset/kitti/training/velodyne/000372.bin
#   inflating: dataset/kitti/training/velodyne/000373.bin
#   inflating: dataset/kitti/training/velodyne/000374.bin
#   inflating: dataset/kitti/training/velodyne/000375.bin
#   inflating: dataset/kitti/training/velodyne/000376.bin
#   inflating: dataset/kitti/training/velodyne/000377.bin
#   inflating: dataset/kitti/training/velodyne/000378.bin
#   inflating: dataset/kitti/training/velodyne/000379.bin
#   inflating: dataset/kitti/training/velodyne/000380.bin
#   inflating: dataset/kitti/training/velodyne/000381.bin
#   inflating: dataset/kitti/training/velodyne/000382.bin
#   inflating: dataset/kitti/training/velodyne/000383.bin
#   inflating: dataset/kitti/training/velodyne/000384.bin
#   inflating: dataset/kitti/training/velodyne/000385.bin
#   inflating: dataset/kitti/training/velodyne/000386.bin
#   inflating: dataset/kitti/training/velodyne/000387.bin
#   inflating: dataset/kitti/training/velodyne/000388.bin
#   inflating: dataset/kitti/training/velodyne/000389.bin
#   inflating: dataset/kitti/training/velodyne/000390.bin
#   inflating: dataset/kitti/training/velodyne/000391.bin
#   inflating: dataset/kitti/training/velodyne/000392.bin
#   inflating: dataset/kitti/training/velodyne/000393.bin
#   inflating: dataset/kitti/training/velodyne/000394.bin
#   inflating: dataset/kitti/training/velodyne/000395.bin
#   inflating: dataset/kitti/training/velodyne/000396.bin
#   inflating: dataset/kitti/training/velodyne/000397.bin
#   inflating: dataset/kitti/training/velodyne/000398.bin
#   inflating: dataset/kitti/training/velodyne/000399.bin
#   inflating: dataset/kitti/training/velodyne/000400.bin
#   inflating: dataset/kitti/training/velodyne/000401.bin
#   inflating: dataset/kitti/training/velodyne/000402.bin
#   inflating: dataset/kitti/training/velodyne/000403.bin
#   inflating: dataset/kitti/training/velodyne/000404.bin
#   inflating: dataset/kitti/training/velodyne/000405.bin
#   inflating: dataset/kitti/training/velodyne/000406.bin
#   inflating: dataset/kitti/training/velodyne/000407.bin
#   inflating: dataset/kitti/training/velodyne/000408.bin
#   inflating: dataset/kitti/training/velodyne/000409.bin
#   inflating: dataset/kitti/training/velodyne/000410.bin
#   inflating: dataset/kitti/training/velodyne/000411.bin
#   inflating: dataset/kitti/training/velodyne/000412.bin
#   inflating: dataset/kitti/training/velodyne/000413.bin
#   inflating: dataset/kitti/training/velodyne/000414.bin
#   inflating: dataset/kitti/training/velodyne/000415.bin
#   inflating: dataset/kitti/training/velodyne/000416.bin
#   inflating: dataset/kitti/training/velodyne/000417.bin
#   inflating: dataset/kitti/training/velodyne/000418.bin
#   inflating: dataset/kitti/training/velodyne/000419.bin
#   inflating: dataset/kitti/training/velodyne/000420.bin
#   inflating: dataset/kitti/training/velodyne/000421.bin
#   inflating: dataset/kitti/training/velodyne/000422.bin
#   inflating: dataset/kitti/training/velodyne/000423.bin
#   inflating: dataset/kitti/training/velodyne/000424.bin
#   inflating: dataset/kitti/training/velodyne/000425.bin
#   inflating: dataset/kitti/training/velodyne/000426.bin
#   inflating: dataset/kitti/training/velodyne/000427.bin
#   inflating: dataset/kitti/training/velodyne/000428.bin
#   inflating: dataset/kitti/training/velodyne/000429.bin
#   inflating: dataset/kitti/training/velodyne/000430.bin
#   inflating: dataset/kitti/training/velodyne/000431.bin
#   inflating: dataset/kitti/training/velodyne/000432.bin
#   inflating: dataset/kitti/training/velodyne/000433.bin
#   inflating: dataset/kitti/training/velodyne/000434.bin
#   inflating: dataset/kitti/training/velodyne/000435.bin
#   inflating: dataset/kitti/training/velodyne/000436.bin
#   inflating: dataset/kitti/training/velodyne/000437.bin
#   inflating: dataset/kitti/training/velodyne/000438.bin
#   inflating: dataset/kitti/training/velodyne/000439.bin
#   inflating: dataset/kitti/training/velodyne/000440.bin
#   inflating: dataset/kitti/training/velodyne/000441.bin
#   inflating: dataset/kitti/training/velodyne/000442.bin
#   inflating: dataset/kitti/training/velodyne/000443.bin
#   inflating: dataset/kitti/training/velodyne/000444.bin
#   inflating: dataset/kitti/training/velodyne/000445.bin
#   inflating: dataset/kitti/training/velodyne/000446.bin
#   inflating: dataset/kitti/training/velodyne/000447.bin
#   inflating: dataset/kitti/training/velodyne/000448.bin
#   inflating: dataset/kitti/training/velodyne/000449.bin
#   inflating: dataset/kitti/training/velodyne/000450.bin
#   inflating: dataset/kitti/training/velodyne/000451.bin
#   inflating: dataset/kitti/training/velodyne/000452.bin
#   inflating: dataset/kitti/training/velodyne/000453.bin
#   inflating: dataset/kitti/training/velodyne/000454.bin
#   inflating: dataset/kitti/training/velodyne/000455.bin
#   inflating: dataset/kitti/training/velodyne/000456.bin
#   inflating: dataset/kitti/training/velodyne/000457.bin
#   inflating: dataset/kitti/training/velodyne/000458.bin
#   inflating: dataset/kitti/training/velodyne/000459.bin
#   inflating: dataset/kitti/training/velodyne/000460.bin
#   inflating: dataset/kitti/training/velodyne/000461.bin
#   inflating: dataset/kitti/training/velodyne/000462.bin
#   inflating: dataset/kitti/training/velodyne/000463.bin
#   inflating: dataset/kitti/training/velodyne/000464.bin
#   inflating: dataset/kitti/training/velodyne/000465.bin
#   inflating: dataset/kitti/training/velodyne/000466.bin
#   inflating: dataset/kitti/training/velodyne/000467.bin
#   inflating: dataset/kitti/training/velodyne/000468.bin
#   inflating: dataset/kitti/training/velodyne/000469.bin
#   inflating: dataset/kitti/training/velodyne/000470.bin
#   inflating: dataset/kitti/training/velodyne/000471.bin
#   inflating: dataset/kitti/training/velodyne/000472.bin
#   inflating: dataset/kitti/training/velodyne/000473.bin
#   inflating: dataset/kitti/training/velodyne/000474.bin
#   inflating: dataset/kitti/training/velodyne/000475.bin
#   inflating: dataset/kitti/training/velodyne/000476.bin
#   inflating: dataset/kitti/training/velodyne/000477.bin
#   inflating: dataset/kitti/training/velodyne/000478.bin
#   inflating: dataset/kitti/training/velodyne/000479.bin
#   inflating: dataset/kitti/training/velodyne/000480.bin
#   inflating: dataset/kitti/training/velodyne/000481.bin
#   inflating: dataset/kitti/training/velodyne/000482.bin
#   inflating: dataset/kitti/training/velodyne/000483.bin
#   inflating: dataset/kitti/training/velodyne/000484.bin
#   inflating: dataset/kitti/training/velodyne/000485.bin
#   inflating: dataset/kitti/training/velodyne/000486.bin
#   inflating: dataset/kitti/training/velodyne/000487.bin
#   inflating: dataset/kitti/training/velodyne/000488.bin
#   inflating: dataset/kitti/training/velodyne/000489.bin
#   inflating: dataset/kitti/training/velodyne/000490.bin
#   inflating: dataset/kitti/training/velodyne/000491.bin
#   inflating: dataset/kitti/training/velodyne/000492.bin
#   inflating: dataset/kitti/training/velodyne/000493.bin
#   inflating: dataset/kitti/training/velodyne/000494.bin
#   inflating: dataset/kitti/training/velodyne/000495.bin
#   inflating: dataset/kitti/training/velodyne/000496.bin
#   inflating: dataset/kitti/training/velodyne/000497.bin
#   inflating: dataset/kitti/training/velodyne/000498.bin
#   inflating: dataset/kitti/training/velodyne/000499.bin
#   inflating: dataset/kitti/training/velodyne/000500.bin
#   inflating: dataset/kitti/training/velodyne/000501.bin
#   inflating: dataset/kitti/training/velodyne/000502.bin
#   inflating: dataset/kitti/training/velodyne/000503.bin
#   inflating: dataset/kitti/training/velodyne/000504.bin
#   inflating: dataset/kitti/training/velodyne/000505.bin
#   inflating: dataset/kitti/training/velodyne/000506.bin
#   inflating: dataset/kitti/training/velodyne/000507.bin
#   inflating: dataset/kitti/training/velodyne/000508.bin
#   inflating: dataset/kitti/training/velodyne/000509.bin
#   inflating: dataset/kitti/training/velodyne/000510.bin
#   inflating: dataset/kitti/training/velodyne/000511.bin
#   inflating: dataset/kitti/training/velodyne/000512.bin
#   inflating: dataset/kitti/training/velodyne/000513.bin
#   inflating: dataset/kitti/training/velodyne/000514.bin
#   inflating: dataset/kitti/training/velodyne/000515.bin
#   inflating: dataset/kitti/training/velodyne/000516.bin
#   inflating: dataset/kitti/training/velodyne/000517.bin
#   inflating: dataset/kitti/training/velodyne/000518.bin
#   inflating: dataset/kitti/training/velodyne/000519.bin
#   inflating: dataset/kitti/training/velodyne/000520.bin
#   inflating: dataset/kitti/training/velodyne/000521.bin
#   inflating: dataset/kitti/training/velodyne/000522.bin
#   inflating: dataset/kitti/training/velodyne/000523.bin
#   inflating: dataset/kitti/training/velodyne/000524.bin
#   inflating: dataset/kitti/training/velodyne/000525.bin
#   inflating: dataset/kitti/training/velodyne/000526.bin
#   inflating: dataset/kitti/training/velodyne/000527.bin
#   inflating: dataset/kitti/training/velodyne/000528.bin
#   inflating: dataset/kitti/training/velodyne/000529.bin
#   inflating: dataset/kitti/training/velodyne/000530.bin
#   inflating: dataset/kitti/training/velodyne/000531.bin
#   inflating: dataset/kitti/training/velodyne/000532.bin
#   inflating: dataset/kitti/training/velodyne/000533.bin
#   inflating: dataset/kitti/training/velodyne/000534.bin
#   inflating: dataset/kitti/training/velodyne/000535.bin
#   inflating: dataset/kitti/training/velodyne/000536.bin
#   inflating: dataset/kitti/training/velodyne/000537.bin
#   inflating: dataset/kitti/training/velodyne/000538.bin
#   inflating: dataset/kitti/training/velodyne/000539.bin
#   inflating: dataset/kitti/training/velodyne/000540.bin
#   inflating: dataset/kitti/training/velodyne/000541.bin
#   inflating: dataset/kitti/training/velodyne/000542.bin
#   inflating: dataset/kitti/training/velodyne/000543.bin
#   inflating: dataset/kitti/training/velodyne/000544.bin
#   inflating: dataset/kitti/training/velodyne/000545.bin
#   inflating: dataset/kitti/training/velodyne/000546.bin
#   inflating: dataset/kitti/training/velodyne/000547.bin
#   inflating: dataset/kitti/training/velodyne/000548.bin
#   inflating: dataset/kitti/training/velodyne/000549.bin
#   inflating: dataset/kitti/training/velodyne/000550.bin
#   inflating: dataset/kitti/training/velodyne/000551.bin
#   inflating: dataset/kitti/training/velodyne/000552.bin
#   inflating: dataset/kitti/training/velodyne/000553.bin
#   inflating: dataset/kitti/training/velodyne/000554.bin
#   inflating: dataset/kitti/training/velodyne/000555.bin
#   inflating: dataset/kitti/training/velodyne/000556.bin
#   inflating: dataset/kitti/training/velodyne/000557.bin
#   inflating: dataset/kitti/training/velodyne/000558.bin
#   inflating: dataset/kitti/training/velodyne/000559.bin
#   inflating: dataset/kitti/training/velodyne/000560.bin
#   inflating: dataset/kitti/training/velodyne/000561.bin
#   inflating: dataset/kitti/training/velodyne/000562.bin
#   inflating: dataset/kitti/training/velodyne/000563.bin
#   inflating: dataset/kitti/training/velodyne/000564.bin
#   inflating: dataset/kitti/training/velodyne/000565.bin
#   inflating: dataset/kitti/training/velodyne/000566.bin
#   inflating: dataset/kitti/training/velodyne/000567.bin
#   inflating: dataset/kitti/training/velodyne/000568.bin
#   inflating: dataset/kitti/training/velodyne/000569.bin
#   inflating: dataset/kitti/training/velodyne/000570.bin
#   inflating: dataset/kitti/training/velodyne/000571.bin
#   inflating: dataset/kitti/training/velodyne/000572.bin
#   inflating: dataset/kitti/training/velodyne/000573.bin
#   inflating: dataset/kitti/training/velodyne/000574.bin
#   inflating: dataset/kitti/training/velodyne/000575.bin
#   inflating: dataset/kitti/training/velodyne/000576.bin
#   inflating: dataset/kitti/training/velodyne/000577.bin
#   inflating: dataset/kitti/training/velodyne/000578.bin
#   inflating: dataset/kitti/training/velodyne/000579.bin
#   inflating: dataset/kitti/training/velodyne/000580.bin
#   inflating: dataset/kitti/training/velodyne/000581.bin
#   inflating: dataset/kitti/training/velodyne/000582.bin
#   inflating: dataset/kitti/training/velodyne/000583.bin
#   inflating: dataset/kitti/training/velodyne/000584.bin
#   inflating: dataset/kitti/training/velodyne/000585.bin
#   inflating: dataset/kitti/training/velodyne/000586.bin
#   inflating: dataset/kitti/training/velodyne/000587.bin
#   inflating: dataset/kitti/training/velodyne/000588.bin
#   inflating: dataset/kitti/training/velodyne/000589.bin
#   inflating: dataset/kitti/training/velodyne/000590.bin
#   inflating: dataset/kitti/training/velodyne/000591.bin
#   inflating: dataset/kitti/training/velodyne/000592.bin
#   inflating: dataset/kitti/training/velodyne/000593.bin
#   inflating: dataset/kitti/training/velodyne/000594.bin
#   inflating: dataset/kitti/training/velodyne/000595.bin
#   inflating: dataset/kitti/training/velodyne/000596.bin
#   inflating: dataset/kitti/training/velodyne/000597.bin
#   inflating: dataset/kitti/training/velodyne/000598.bin
#   inflating: dataset/kitti/training/velodyne/000599.bin
#   inflating: dataset/kitti/training/velodyne/000600.bin
#   inflating: dataset/kitti/training/velodyne/000601.bin
#   inflating: dataset/kitti/training/velodyne/000602.bin
#   inflating: dataset/kitti/training/velodyne/000603.bin
#   inflating: dataset/kitti/training/velodyne/000604.bin
#   inflating: dataset/kitti/training/velodyne/000605.bin
#   inflating: dataset/kitti/training/velodyne/000606.bin
#   inflating: dataset/kitti/training/velodyne/000607.bin
#   inflating: dataset/kitti/training/velodyne/000608.bin
#   inflating: dataset/kitti/training/velodyne/000609.bin
#   inflating: dataset/kitti/training/velodyne/000610.bin
#   inflating: dataset/kitti/training/velodyne/000611.bin
#   inflating: dataset/kitti/training/velodyne/000612.bin
#   inflating: dataset/kitti/training/velodyne/000613.bin
#   inflating: dataset/kitti/training/velodyne/000614.bin
#   inflating: dataset/kitti/training/velodyne/000615.bin
#   inflating: dataset/kitti/training/velodyne/000616.bin
#   inflating: dataset/kitti/training/velodyne/000617.bin
#   inflating: dataset/kitti/training/velodyne/000618.bin
#   inflating: dataset/kitti/training/velodyne/000619.bin
#   inflating: dataset/kitti/training/velodyne/000620.bin
#   inflating: dataset/kitti/training/velodyne/000621.bin
#   inflating: dataset/kitti/training/velodyne/000622.bin
#   inflating: dataset/kitti/training/velodyne/000623.bin
#   inflating: dataset/kitti/training/velodyne/000624.bin
#   inflating: dataset/kitti/training/velodyne/000625.bin
#   inflating: dataset/kitti/training/velodyne/000626.bin
#   inflating: dataset/kitti/training/velodyne/000627.bin
#   inflating: dataset/kitti/training/velodyne/000628.bin
#   inflating: dataset/kitti/training/velodyne/000629.bin
#   inflating: dataset/kitti/training/velodyne/000630.bin
#   inflating: dataset/kitti/training/velodyne/000631.bin
#   inflating: dataset/kitti/training/velodyne/000632.bin
#   inflating: dataset/kitti/training/velodyne/000633.bin
#   inflating: dataset/kitti/training/velodyne/000634.bin
#   inflating: dataset/kitti/training/velodyne/000635.bin
#   inflating: dataset/kitti/training/velodyne/000636.bin
#   inflating: dataset/kitti/training/velodyne/000637.bin
#   inflating: dataset/kitti/training/velodyne/000638.bin
#   inflating: dataset/kitti/training/velodyne/000639.bin
#   inflating: dataset/kitti/training/velodyne/000640.bin
#   inflating: dataset/kitti/training/velodyne/000641.bin
#   inflating: dataset/kitti/training/velodyne/000642.bin
#   inflating: dataset/kitti/training/velodyne/000643.bin
#   inflating: dataset/kitti/training/velodyne/000644.bin
#   inflating: dataset/kitti/training/velodyne/000645.bin
#   inflating: dataset/kitti/training/velodyne/000646.bin
#   inflating: dataset/kitti/training/velodyne/000647.bin
#   inflating: dataset/kitti/training/velodyne/000648.bin
#   inflating: dataset/kitti/training/velodyne/000649.bin
#   inflating: dataset/kitti/training/velodyne/000650.bin
#   inflating: dataset/kitti/training/velodyne/000651.bin
#   inflating: dataset/kitti/training/velodyne/000652.bin
#   inflating: dataset/kitti/training/velodyne/000653.bin
#   inflating: dataset/kitti/training/velodyne/000654.bin
#   inflating: dataset/kitti/training/velodyne/000655.bin
#   inflating: dataset/kitti/training/velodyne/000656.bin
#   inflating: dataset/kitti/training/velodyne/000657.bin
#   inflating: dataset/kitti/training/velodyne/000658.bin
#   inflating: dataset/kitti/training/velodyne/000659.bin
#   inflating: dataset/kitti/training/velodyne/000660.bin
#   inflating: dataset/kitti/training/velodyne/000661.bin
#   inflating: dataset/kitti/training/velodyne/000662.bin
#   inflating: dataset/kitti/training/velodyne/000663.bin
#   inflating: dataset/kitti/training/velodyne/000664.bin
#   inflating: dataset/kitti/training/velodyne/000665.bin
#   inflating: dataset/kitti/training/velodyne/000666.bin
#   inflating: dataset/kitti/training/velodyne/000667.bin
#   inflating: dataset/kitti/training/velodyne/000668.bin
#   inflating: dataset/kitti/training/velodyne/000669.bin
#   inflating: dataset/kitti/training/velodyne/000670.bin
#   inflating: dataset/kitti/training/velodyne/000671.bin
#   inflating: dataset/kitti/training/velodyne/000672.bin
#   inflating: dataset/kitti/training/velodyne/000673.bin
#   inflating: dataset/kitti/training/velodyne/000674.bin
#   inflating: dataset/kitti/training/velodyne/000675.bin
#   inflating: dataset/kitti/training/velodyne/000676.bin
#   inflating: dataset/kitti/training/velodyne/000677.bin
#   inflating: dataset/kitti/training/velodyne/000678.bin
#   inflating: dataset/kitti/training/velodyne/000679.bin
#   inflating: dataset/kitti/training/velodyne/000680.bin
#   inflating: dataset/kitti/training/velodyne/000681.bin
#   inflating: dataset/kitti/training/velodyne/000682.bin
#   inflating: dataset/kitti/training/velodyne/000683.bin
#   inflating: dataset/kitti/training/velodyne/000684.bin
#   inflating: dataset/kitti/training/velodyne/000685.bin
#   inflating: dataset/kitti/training/velodyne/000686.bin
#   inflating: dataset/kitti/training/velodyne/000687.bin
#   inflating: dataset/kitti/training/velodyne/000688.bin
#   inflating: dataset/kitti/training/velodyne/000689.bin
#   inflating: dataset/kitti/training/velodyne/000690.bin
#   inflating: dataset/kitti/training/velodyne/000691.bin
#   inflating: dataset/kitti/training/velodyne/000692.bin
#   inflating: dataset/kitti/training/velodyne/000693.bin
#   inflating: dataset/kitti/training/velodyne/000694.bin
#   inflating: dataset/kitti/training/velodyne/000695.bin
#   inflating: dataset/kitti/training/velodyne/000696.bin
#   inflating: dataset/kitti/training/velodyne/000697.bin
#   inflating: dataset/kitti/training/velodyne/000698.bin
#   inflating: dataset/kitti/training/velodyne/000699.bin
#   inflating: dataset/kitti/training/velodyne/000700.bin
#   inflating: dataset/kitti/training/velodyne/000701.bin
#   inflating: dataset/kitti/training/velodyne/000702.bin
#   inflating: dataset/kitti/training/velodyne/000703.bin
#   inflating: dataset/kitti/training/velodyne/000704.bin
#   inflating: dataset/kitti/training/velodyne/000705.bin
#   inflating: dataset/kitti/training/velodyne/000706.bin
#   inflating: dataset/kitti/training/velodyne/000707.bin
#   inflating: dataset/kitti/training/velodyne/000708.bin
#   inflating: dataset/kitti/training/velodyne/000709.bin
#   inflating: dataset/kitti/training/velodyne/000710.bin
#   inflating: dataset/kitti/training/velodyne/000711.bin
#   inflating: dataset/kitti/training/velodyne/000712.bin
#   inflating: dataset/kitti/training/velodyne/000713.bin
#   inflating: dataset/kitti/training/velodyne/000714.bin
#   inflating: dataset/kitti/training/velodyne/000715.bin
#   inflating: dataset/kitti/training/velodyne/000716.bin
#   inflating: dataset/kitti/training/velodyne/000717.bin
#   inflating: dataset/kitti/training/velodyne/000718.bin
#   inflating: dataset/kitti/training/velodyne/000719.bin
#   inflating: dataset/kitti/training/velodyne/000720.bin
#   inflating: dataset/kitti/training/velodyne/000721.bin
#   inflating: dataset/kitti/training/velodyne/000722.bin
#   inflating: dataset/kitti/training/velodyne/000723.bin
#   inflating: dataset/kitti/training/velodyne/000724.bin
#   inflating: dataset/kitti/training/velodyne/000725.bin
#   inflating: dataset/kitti/training/velodyne/000726.bin
#   inflating: dataset/kitti/training/velodyne/000727.bin
#   inflating: dataset/kitti/training/velodyne/000728.bin
#   inflating: dataset/kitti/training/velodyne/000729.bin
#   inflating: dataset/kitti/training/velodyne/000730.bin
#   inflating: dataset/kitti/training/velodyne/000731.bin
#   inflating: dataset/kitti/training/velodyne/000732.bin
#   inflating: dataset/kitti/training/velodyne/000733.bin
#   inflating: dataset/kitti/training/velodyne/000734.bin
#   inflating: dataset/kitti/training/velodyne/000735.bin
#   inflating: dataset/kitti/training/velodyne/000736.bin
#   inflating: dataset/kitti/training/velodyne/000737.bin
#   inflating: dataset/kitti/training/velodyne/000738.bin
#   inflating: dataset/kitti/training/velodyne/000739.bin
#   inflating: dataset/kitti/training/velodyne/000740.bin
#   inflating: dataset/kitti/training/velodyne/000741.bin
#   inflating: dataset/kitti/training/velodyne/000742.bin
#   inflating: dataset/kitti/training/velodyne/000743.bin
#   inflating: dataset/kitti/training/velodyne/000744.bin
#   inflating: dataset/kitti/training/velodyne/000745.bin
#   inflating: dataset/kitti/training/velodyne/000746.bin
#   inflating: dataset/kitti/training/velodyne/000747.bin
#   inflating: dataset/kitti/training/velodyne/000748.bin
#   inflating: dataset/kitti/training/velodyne/000749.bin
#   inflating: dataset/kitti/training/velodyne/000750.bin
#   inflating: dataset/kitti/training/velodyne/000751.bin
#   inflating: dataset/kitti/training/velodyne/000752.bin
#   inflating: dataset/kitti/training/velodyne/000753.bin
#   inflating: dataset/kitti/training/velodyne/000754.bin
#   inflating: dataset/kitti/training/velodyne/000755.bin
#   inflating: dataset/kitti/training/velodyne/000756.bin
#   inflating: dataset/kitti/training/velodyne/000757.bin
#   inflating: dataset/kitti/training/velodyne/000758.bin
#   inflating: dataset/kitti/training/velodyne/000759.bin
#   inflating: dataset/kitti/training/velodyne/000760.bin
#   inflating: dataset/kitti/training/velodyne/000761.bin
#   inflating: dataset/kitti/training/velodyne/000762.bin
#   inflating: dataset/kitti/training/velodyne/000763.bin
#   inflating: dataset/kitti/training/velodyne/000764.bin
#   inflating: dataset/kitti/training/velodyne/000765.bin
#   inflating: dataset/kitti/training/velodyne/000766.bin
#   inflating: dataset/kitti/training/velodyne/000767.bin
#   inflating: dataset/kitti/training/velodyne/000768.bin
#   inflating: dataset/kitti/training/velodyne/000769.bin
#   inflating: dataset/kitti/training/velodyne/000770.bin
#   inflating: dataset/kitti/training/velodyne/000771.bin
#   inflating: dataset/kitti/training/velodyne/000772.bin
#   inflating: dataset/kitti/training/velodyne/000773.bin
#   inflating: dataset/kitti/training/velodyne/000774.bin
#   inflating: dataset/kitti/training/velodyne/000775.bin
#   inflating: dataset/kitti/training/velodyne/000776.bin
#   inflating: dataset/kitti/training/velodyne/000777.bin
#   inflating: dataset/kitti/training/velodyne/000778.bin
#   inflating: dataset/kitti/training/velodyne/000779.bin
#   inflating: dataset/kitti/training/velodyne/000780.bin
#   inflating: dataset/kitti/training/velodyne/000781.bin
#   inflating: dataset/kitti/training/velodyne/000782.bin
#   inflating: dataset/kitti/training/velodyne/000783.bin
#   inflating: dataset/kitti/training/velodyne/000784.bin
#   inflating: dataset/kitti/training/velodyne/000785.bin
#   inflating: dataset/kitti/training/velodyne/000786.bin
#   inflating: dataset/kitti/training/velodyne/000787.bin
#   inflating: dataset/kitti/training/velodyne/000788.bin
#   inflating: dataset/kitti/training/velodyne/000789.bin
#   inflating: dataset/kitti/training/velodyne/000790.bin
#   inflating: dataset/kitti/training/velodyne/000791.bin
#   inflating: dataset/kitti/training/velodyne/000792.bin
#   inflating: dataset/kitti/training/velodyne/000793.bin
#   inflating: dataset/kitti/training/velodyne/000794.bin
#   inflating: dataset/kitti/training/velodyne/000795.bin
#   inflating: dataset/kitti/training/velodyne/000796.bin
#   inflating: dataset/kitti/training/velodyne/000797.bin
#   inflating: dataset/kitti/training/velodyne/000798.bin
#   inflating: dataset/kitti/training/velodyne/000799.bin
#   inflating: dataset/kitti/training/velodyne/000800.bin
#   inflating: dataset/kitti/training/velodyne/000801.bin
#   inflating: dataset/kitti/training/velodyne/000802.bin
#   inflating: dataset/kitti/training/velodyne/000803.bin
#   inflating: dataset/kitti/training/velodyne/000804.bin
#   inflating: dataset/kitti/training/velodyne/000805.bin
#   inflating: dataset/kitti/training/velodyne/000806.bin
#   inflating: dataset/kitti/training/velodyne/000807.bin
#   inflating: dataset/kitti/training/velodyne/000808.bin
#   inflating: dataset/kitti/training/velodyne/000809.bin
#   inflating: dataset/kitti/training/velodyne/000810.bin
#   inflating: dataset/kitti/training/velodyne/000811.bin
#   inflating: dataset/kitti/training/velodyne/000812.bin
#   inflating: dataset/kitti/training/velodyne/000813.bin
#   inflating: dataset/kitti/training/velodyne/000814.bin
#   inflating: dataset/kitti/training/velodyne/000815.bin
#   inflating: dataset/kitti/training/velodyne/000816.bin
#   inflating: dataset/kitti/training/velodyne/000817.bin
#   inflating: dataset/kitti/training/velodyne/000818.bin
#   inflating: dataset/kitti/training/velodyne/000819.bin
#   inflating: dataset/kitti/training/velodyne/000820.bin
#   inflating: dataset/kitti/training/velodyne/000821.bin
#   inflating: dataset/kitti/training/velodyne/000822.bin
#   inflating: dataset/kitti/training/velodyne/000823.bin
#   inflating: dataset/kitti/training/velodyne/000824.bin
#   inflating: dataset/kitti/training/velodyne/000825.bin
# ...
#   inflating: dataset/kitti/training/velodyne/007206.bin
#   inflating: dataset/kitti/training/velodyne/007207.bin
#   inflating: dataset/kitti/training/velodyne/007208.bin
#   inflating: dataset/kitti/training/velodyne/007209.bin
#   inflating: dataset/kitti/training/velodyne/007210.bin
#   inflating: dataset/kitti/training/velodyne/007211.bin
#   inflating: dataset/kitti/training/velodyne/007212.bin
#   inflating: dataset/kitti/training/velodyne/007213.bin
#   inflating: dataset/kitti/training/velodyne/007214.bin
#   inflating: dataset/kitti/training/velodyne/007215.bin
#   inflating: dataset/kitti/training/velodyne/007216.bin
#   inflating: dataset/kitti/training/velodyne/007217.bin
#   inflating: dataset/kitti/training/velodyne/007218.bin
#   inflating: dataset/kitti/training/velodyne/007219.bin
#   inflating: dataset/kitti/training/velodyne/007220.bin
#   inflating: dataset/kitti/training/velodyne/007221.bin
#   inflating: dataset/kitti/training/velodyne/007222.bin
#   inflating: dataset/kitti/training/velodyne/007223.bin
#   inflating: dataset/kitti/training/velodyne/007224.bin
#   inflating: dataset/kitti/training/velodyne/007225.bin
#   inflating: dataset/kitti/training/velodyne/007226.bin
#   inflating: dataset/kitti/training/velodyne/007227.bin
#   inflating: dataset/kitti/training/velodyne/007228.bin
#   inflating: dataset/kitti/training/velodyne/007229.bin
#   inflating: dataset/kitti/training/velodyne/007230.bin
#   inflating: dataset/kitti/training/velodyne/007231.bin
#   inflating: dataset/kitti/training/velodyne/007232.bin
#   inflating: dataset/kitti/training/velodyne/007233.bin
#   inflating: dataset/kitti/training/velodyne/007234.bin
#   inflating: dataset/kitti/training/velodyne/007235.bin
#   inflating: dataset/kitti/training/velodyne/007236.bin
#   inflating: dataset/kitti/training/velodyne/007237.bin
#   inflating: dataset/kitti/training/velodyne/007238.bin
#   inflating: dataset/kitti/training/velodyne/007239.bin
#   inflating: dataset/kitti/training/velodyne/007240.bin
#   inflating: dataset/kitti/training/velodyne/007241.bin
#   inflating: dataset/kitti/training/velodyne/007242.bin
#   inflating: dataset/kitti/training/velodyne/007243.bin
#   inflating: dataset/kitti/training/velodyne/007244.bin
#   inflating: dataset/kitti/training/velodyne/007245.bin
#   inflating: dataset/kitti/training/velodyne/007246.bin
#   inflating: dataset/kitti/training/velodyne/007247.bin
#   inflating: dataset/kitti/training/velodyne/007248.bin
#   inflating: dataset/kitti/training/velodyne/007249.bin
#   inflating: dataset/kitti/training/velodyne/007250.bin
#   inflating: dataset/kitti/training/velodyne/007251.bin
#   inflating: dataset/kitti/training/velodyne/007252.bin
#   inflating: dataset/kitti/training/velodyne/007253.bin
#   inflating: dataset/kitti/training/velodyne/007254.bin
#   inflating: dataset/kitti/training/velodyne/007255.bin
#   inflating: dataset/kitti/training/velodyne/007256.bin
#   inflating: dataset/kitti/training/velodyne/007257.bin
#   inflating: dataset/kitti/training/velodyne/007258.bin
#   inflating: dataset/kitti/training/velodyne/007259.bin
#   inflating: dataset/kitti/training/velodyne/007260.bin
#   inflating: dataset/kitti/training/velodyne/007261.bin
#   inflating: dataset/kitti/training/velodyne/007262.bin
#   inflating: dataset/kitti/training/velodyne/007263.bin
#   inflating: dataset/kitti/training/velodyne/007264.bin
#   inflating: dataset/kitti/training/velodyne/007265.bin
#   inflating: dataset/kitti/training/velodyne/007266.bin
#   inflating: dataset/kitti/training/velodyne/007267.bin
#   inflating: dataset/kitti/training/velodyne/007268.bin
#   inflating: dataset/kitti/training/velodyne/007269.bin
#   inflating: dataset/kitti/training/velodyne/007270.bin
#   inflating: dataset/kitti/training/velodyne/007271.bin
#   inflating: dataset/kitti/training/velodyne/007272.bin
#   inflating: dataset/kitti/training/velodyne/007273.bin
#   inflating: dataset/kitti/training/velodyne/007274.bin
#   inflating: dataset/kitti/training/velodyne/007275.bin
#   inflating: dataset/kitti/training/velodyne/007276.bin
#   inflating: dataset/kitti/training/velodyne/007277.bin
#   inflating: dataset/kitti/training/velodyne/007278.bin
#   inflating: dataset/kitti/training/velodyne/007279.bin
#   inflating: dataset/kitti/training/velodyne/007280.bin
#   inflating: dataset/kitti/training/velodyne/007281.bin
#   inflating: dataset/kitti/training/velodyne/007282.bin
#   inflating: dataset/kitti/training/velodyne/007283.bin
#   inflating: dataset/kitti/training/velodyne/007284.bin
#   inflating: dataset/kitti/training/velodyne/007285.bin
#   inflating: dataset/kitti/training/velodyne/007286.bin
#   inflating: dataset/kitti/training/velodyne/007287.bin
#   inflating: dataset/kitti/training/velodyne/007288.bin
#   inflating: dataset/kitti/training/velodyne/007289.bin
#   inflating: dataset/kitti/training/velodyne/007290.bin
#   inflating: dataset/kitti/training/velodyne/007291.bin
#   inflating: dataset/kitti/training/velodyne/007292.bin
#   inflating: dataset/kitti/training/velodyne/007293.bin
#   inflating: dataset/kitti/training/velodyne/007294.bin
#   inflating: dataset/kitti/training/velodyne/007295.bin
#   inflating: dataset/kitti/training/velodyne/007296.bin
#   inflating: dataset/kitti/training/velodyne/007297.bin
#   inflating: dataset/kitti/training/velodyne/007298.bin
#   inflating: dataset/kitti/training/velodyne/007299.bin
#   inflating: dataset/kitti/training/velodyne/007300.bin
#   inflating: dataset/kitti/training/velodyne/007301.bin
#   inflating: dataset/kitti/training/velodyne/007302.bin
#   inflating: dataset/kitti/training/velodyne/007303.bin
#   inflating: dataset/kitti/training/velodyne/007304.bin
#   inflating: dataset/kitti/training/velodyne/007305.bin
#   inflating: dataset/kitti/training/velodyne/007306.bin
#   inflating: dataset/kitti/training/velodyne/007307.bin
#   inflating: dataset/kitti/training/velodyne/007308.bin
#   inflating: dataset/kitti/training/velodyne/007309.bin
#   inflating: dataset/kitti/training/velodyne/007310.bin
#   inflating: dataset/kitti/training/velodyne/007311.bin
#   inflating: dataset/kitti/training/velodyne/007312.bin
#   inflating: dataset/kitti/training/velodyne/007313.bin
#   inflating: dataset/kitti/training/velodyne/007314.bin
#   inflating: dataset/kitti/training/velodyne/007315.bin
#   inflating: dataset/kitti/training/velodyne/007316.bin
#   inflating: dataset/kitti/training/velodyne/007317.bin
#   inflating: dataset/kitti/training/velodyne/007318.bin
#   inflating: dataset/kitti/training/velodyne/007319.bin
#   inflating: dataset/kitti/training/velodyne/007320.bin
#   inflating: dataset/kitti/training/velodyne/007321.bin
#   inflating: dataset/kitti/training/velodyne/007322.bin
#   inflating: dataset/kitti/training/velodyne/007323.bin
#   inflating: dataset/kitti/training/velodyne/007324.bin
#   inflating: dataset/kitti/training/velodyne/007325.bin
#   inflating: dataset/kitti/training/velodyne/007326.bin
#   inflating: dataset/kitti/training/velodyne/007327.bin
#   inflating: dataset/kitti/training/velodyne/007328.bin
#   inflating: dataset/kitti/training/velodyne/007329.bin
#   inflating: dataset/kitti/training/velodyne/007330.bin
#   inflating: dataset/kitti/training/velodyne/007331.bin
#   inflating: dataset/kitti/training/velodyne/007332.bin
#   inflating: dataset/kitti/training/velodyne/007333.bin
#   inflating: dataset/kitti/training/velodyne/007334.bin
#   inflating: dataset/kitti/training/velodyne/007335.bin
#   inflating: dataset/kitti/training/velodyne/007336.bin
#   inflating: dataset/kitti/training/velodyne/007337.bin
#   inflating: dataset/kitti/training/velodyne/007338.bin
#   inflating: dataset/kitti/training/velodyne/007339.bin
#   inflating: dataset/kitti/training/velodyne/007340.bin
#   inflating: dataset/kitti/training/velodyne/007341.bin
#   inflating: dataset/kitti/training/velodyne/007342.bin
#   inflating: dataset/kitti/training/velodyne/007343.bin
#   inflating: dataset/kitti/training/velodyne/007344.bin
#   inflating: dataset/kitti/training/velodyne/007345.bin
#   inflating: dataset/kitti/training/velodyne/007346.bin
#   inflating: dataset/kitti/training/velodyne/007347.bin
#   inflating: dataset/kitti/training/velodyne/007348.bin
#   inflating: dataset/kitti/training/velodyne/007349.bin
#   inflating: dataset/kitti/training/velodyne/007350.bin
#   inflating: dataset/kitti/training/velodyne/007351.bin
#   inflating: dataset/kitti/training/velodyne/007352.bin
#   inflating: dataset/kitti/training/velodyne/007353.bin
#   inflating: dataset/kitti/training/velodyne/007354.bin
#   inflating: dataset/kitti/training/velodyne/007355.bin
#   inflating: dataset/kitti/training/velodyne/007356.bin
#   inflating: dataset/kitti/training/velodyne/007357.bin
#   inflating: dataset/kitti/training/velodyne/007358.bin
#   inflating: dataset/kitti/training/velodyne/007359.bin
#   inflating: dataset/kitti/training/velodyne/007360.bin
#   inflating: dataset/kitti/training/velodyne/007361.bin
#   inflating: dataset/kitti/training/velodyne/007362.bin
#   inflating: dataset/kitti/training/velodyne/007363.bin
#   inflating: dataset/kitti/training/velodyne/007364.bin
#   inflating: dataset/kitti/training/velodyne/007365.bin
#   inflating: dataset/kitti/training/velodyne/007366.bin
#   inflating: dataset/kitti/training/velodyne/007367.bin
#   inflating: dataset/kitti/training/velodyne/007368.bin
#   inflating: dataset/kitti/training/velodyne/007369.bin
#   inflating: dataset/kitti/training/velodyne/007370.bin
#   inflating: dataset/kitti/training/velodyne/007371.bin
#   inflating: dataset/kitti/training/velodyne/007372.bin
#   inflating: dataset/kitti/training/velodyne/007373.bin
#   inflating: dataset/kitti/training/velodyne/007374.bin
#   inflating: dataset/kitti/training/velodyne/007375.bin
#   inflating: dataset/kitti/training/velodyne/007376.bin
#   inflating: dataset/kitti/training/velodyne/007377.bin
#   inflating: dataset/kitti/training/velodyne/007378.bin
#   inflating: dataset/kitti/training/velodyne/007379.bin
#   inflating: dataset/kitti/training/velodyne/007380.bin
#   inflating: dataset/kitti/training/velodyne/007381.bin
#   inflating: dataset/kitti/training/velodyne/007382.bin
#   inflating: dataset/kitti/training/velodyne/007383.bin
#   inflating: dataset/kitti/training/velodyne/007384.bin
#   inflating: dataset/kitti/training/velodyne/007385.bin
#   inflating: dataset/kitti/training/velodyne/007386.bin
#   inflating: dataset/kitti/training/velodyne/007387.bin
#   inflating: dataset/kitti/training/velodyne/007388.bin
#   inflating: dataset/kitti/training/velodyne/007389.bin
#   inflating: dataset/kitti/training/velodyne/007390.bin
#   inflating: dataset/kitti/training/velodyne/007391.bin
#   inflating: dataset/kitti/training/velodyne/007392.bin
#   inflating: dataset/kitti/training/velodyne/007393.bin
#   inflating: dataset/kitti/training/velodyne/007394.bin
#   inflating: dataset/kitti/training/velodyne/007395.bin
#   inflating: dataset/kitti/training/velodyne/007396.bin
#   inflating: dataset/kitti/training/velodyne/007397.bin
#   inflating: dataset/kitti/training/velodyne/007398.bin
#   inflating: dataset/kitti/training/velodyne/007399.bin
#   inflating: dataset/kitti/training/velodyne/007400.bin
#   inflating: dataset/kitti/training/velodyne/007401.bin
#   inflating: dataset/kitti/training/velodyne/007402.bin
#   inflating: dataset/kitti/training/velodyne/007403.bin
#   inflating: dataset/kitti/training/velodyne/007404.bin
#   inflating: dataset/kitti/training/velodyne/007405.bin
#   inflating: dataset/kitti/training/velodyne/007406.bin
#   inflating: dataset/kitti/training/velodyne/007407.bin
#   inflating: dataset/kitti/training/velodyne/007408.bin
#   inflating: dataset/kitti/training/velodyne/007409.bin
#   inflating: dataset/kitti/training/velodyne/007410.bin
#   inflating: dataset/kitti/training/velodyne/007411.bin
#   inflating: dataset/kitti/training/velodyne/007412.bin
#   inflating: dataset/kitti/training/velodyne/007413.bin
#   inflating: dataset/kitti/training/velodyne/007414.bin
#   inflating: dataset/kitti/training/velodyne/007415.bin
#   inflating: dataset/kitti/training/velodyne/007416.bin
#   inflating: dataset/kitti/training/velodyne/007417.bin
#   inflating: dataset/kitti/training/velodyne/007418.bin
#   inflating: dataset/kitti/training/velodyne/007419.bin
#   inflating: dataset/kitti/training/velodyne/007420.bin
#   inflating: dataset/kitti/training/velodyne/007421.bin
#   inflating: dataset/kitti/training/velodyne/007422.bin
#   inflating: dataset/kitti/training/velodyne/007423.bin
#   inflating: dataset/kitti/training/velodyne/007424.bin
#   inflating: dataset/kitti/training/velodyne/007425.bin
#   inflating: dataset/kitti/training/velodyne/007426.bin
#   inflating: dataset/kitti/training/velodyne/007427.bin
#   inflating: dataset/kitti/training/velodyne/007428.bin
#   inflating: dataset/kitti/training/velodyne/007429.bin
#   inflating: dataset/kitti/training/velodyne/007430.bin
#   inflating: dataset/kitti/training/velodyne/007431.bin
#   inflating: dataset/kitti/training/velodyne/007432.bin
#   inflating: dataset/kitti/training/velodyne/007433.bin
#   inflating: dataset/kitti/training/velodyne/007434.bin
#   inflating: dataset/kitti/training/velodyne/007435.bin
#   inflating: dataset/kitti/training/velodyne/007436.bin
#   inflating: dataset/kitti/training/velodyne/007437.bin
#   inflating: dataset/kitti/training/velodyne/007438.bin
#   inflating: dataset/kitti/training/velodyne/007439.bin
#   inflating: dataset/kitti/training/velodyne/007440.bin
#   inflating: dataset/kitti/training/velodyne/007441.bin
#   inflating: dataset/kitti/training/velodyne/007442.bin
#   inflating: dataset/kitti/training/velodyne/007443.bin
#   inflating: dataset/kitti/training/velodyne/007444.bin
#   inflating: dataset/kitti/training/velodyne/007445.bin
#   inflating: dataset/kitti/training/velodyne/007446.bin
#   inflating: dataset/kitti/training/velodyne/007447.bin
#   inflating: dataset/kitti/training/velodyne/007448.bin
#   inflating: dataset/kitti/training/velodyne/007449.bin
#   inflating: dataset/kitti/training/velodyne/007450.bin
#   inflating: dataset/kitti/training/velodyne/007451.bin
#   inflating: dataset/kitti/training/velodyne/007452.bin
#   inflating: dataset/kitti/training/velodyne/007453.bin
#   inflating: dataset/kitti/training/velodyne/007454.bin
#   inflating: dataset/kitti/training/velodyne/007455.bin
#   inflating: dataset/kitti/training/velodyne/007456.bin
#   inflating: dataset/kitti/training/velodyne/007457.bin
#   inflating: dataset/kitti/training/velodyne/007458.bin
#   inflating: dataset/kitti/training/velodyne/007459.bin
#   inflating: dataset/kitti/training/velodyne/007460.bin
#   inflating: dataset/kitti/training/velodyne/007461.bin
#   inflating: dataset/kitti/training/velodyne/007462.bin
#   inflating: dataset/kitti/training/velodyne/007463.bin
#   inflating: dataset/kitti/training/velodyne/007464.bin
#   inflating: dataset/kitti/training/velodyne/007465.bin
#   inflating: dataset/kitti/training/velodyne/007466.bin
#   inflating: dataset/kitti/training/velodyne/007467.bin
#   inflating: dataset/kitti/training/velodyne/007468.bin
#   inflating: dataset/kitti/training/velodyne/007469.bin
#   inflating: dataset/kitti/training/velodyne/007470.bin
#   inflating: dataset/kitti/training/velodyne/007471.bin
#   inflating: dataset/kitti/training/velodyne/007472.bin
#   inflating: dataset/kitti/training/velodyne/007473.bin
#   inflating: dataset/kitti/training/velodyne/007474.bin
#   inflating: dataset/kitti/training/velodyne/007475.bin
#   inflating: dataset/kitti/training/velodyne/007476.bin
#   inflating: dataset/kitti/training/velodyne/007477.bin
#   inflating: dataset/kitti/training/velodyne/007478.bin
#   inflating: dataset/kitti/training/velodyne/007479.bin
#   inflating: dataset/kitti/training/velodyne/007480.bin

# %% [markdown]
# # 5. [Opt] Check Memory Space

# %%
# Memory Space
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 17.2 gigabytes of available RAM
#
# To enable a high-RAM runtime, select the Runtime > "Change runtime type"
# menu, and then select High-RAM in the Runtime shape dropdown. Then,
# re-execute this cell.

# %% [markdown]
# # 6. install terminaltables for Ascii Table print

# %%
# !pip install terminaltables #
# Out:
# Requirement already satisfied: terminaltables in ./.venv/lib/python3.11/site-packages (3.1.10)

# %%
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
# ! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
# ! wget https://pjreddie.com/media/files/yolov3.weights
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import shutil
# shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
# shutil.move("/content/yolov3.weights", "/content/checkpoints")
shutil.move("/content/yolov4-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov4.weights", "/content/checkpoints") 
shutil.rmtree("sample_data")
# Out:
# zsh:1: command not found: wget
# zsh:1: command not found: wget
#   1%|          | 81.3M/7.81G [29:35<46:52:54, 45.8kB/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:825, in move(src, dst, copy_function)
#     824 try:
# --> 825     os.rename(src, real_dst)
#     826 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/yolov4-tiny.weights' -> '/content/checkpoints'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 10
#       7 import shutil
#       8 # shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
#       9 # shutil.move("/content/yolov3.weights", "/content/checkpoints")
# ---> 10 shutil.move("/content/yolov4-tiny.weights", "/content/checkpoints")
#      11 shutil.move("/content/yolov4.weights", "/content/checkpoints")
#      12 shutil.rmtree("sample_data")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:845, in move(src, dst, copy_function)
#     843         rmtree(src)
#     844     else:
# --> 845         copy_function(src, real_dst)
#     846         os.unlink(src)
#     847 return real_dst
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:436, in copy2(src, dst, follow_symlinks)
#     434 if os.path.isdir(dst):
#     435     dst = os.path.join(dst, os.path.basename(src))
# --> 436 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     437 copystat(src, dst, follow_symlinks=follow_symlinks)
#     438 return dst
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:256, in copyfile(src, dst, follow_symlinks)
#     254     os.symlink(os.readlink(src), dst)
#     255 else:
# --> 256     with open(src, 'rb') as fsrc:
#     257         try:
#     258             with open(dst, 'wb') as fdst:
#     259                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/yolov4-tiny.weights'

# %% [markdown]
# # 8. Complex Yolo - Yolo V4 Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1pyTkEUCtPrLWGHkDaviZNlM7U13eCmkg'
output_name = 'Complex_yolo_yolo_v4.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1pyTkEUCtPrLWGHkDaviZNlM7U13eCmkg/view?usp=sharing
shutil.move("/Complex_yolo_yolo_v4.pth", "/checkpoints")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:825, in move(src, dst, copy_function)
#     824 try:
# --> 825     os.rename(src, real_dst)
#     826 except OSError:
#
# OSError: [Errno 18] Cross-device link: 'Complex_yolo_yolo_v4.pth' -> '/checkpoints'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 6
#       1 # google_path = 'https://drive.google.com/uc?id='
#       2 # file_id = '1pyTkEUCtPrLWGHkDaviZNlM7U13eCmkg'
#       3 # output_name = 'Complex_yolo_yolo_v4.pth'
#       4 # gdown.download(google_path+file_id,output_name,quiet=False)
#       5 # https://drive.google.com/file/d/1pyTkEUCtPrLWGHkDaviZNlM7U13eCmkg/view?usp=sharing
# ----> 6 shutil.move("Complex_yolo_yolo_v4.pth", "/checkpoints")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:845, in move(src, dst, copy_function)
#     843         rmtree(src)
#     844     else:
# --> 845         copy_function(src, real_dst)
#     846         os.unlink(src)
#     847 return real_dst
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:436, in copy2(src, dst, follow_symlinks)
#     434 if os.path.isdir(dst):
#     435     dst = os.path.join(dst, os.path.basename(src))
# --> 436 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     437 copystat(src, dst, follow_symlinks=follow_symlinks)
#     438 return dst
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:258, in copyfile(src, dst, follow_symlinks)
#     256 with open(src, 'rb') as fsrc:
#     257     try:
# --> 258         with open(dst, 'wb') as fdst:
#     259             # macOS
#     260             if _HAS_FCOPYFILE:
#     261                 try:
#
# OSError: [Errno 30] Read-only file system: '/checkpoints'

# %% [markdown]
# # 9. Complex Yolo - Yolo V4-tiny Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1Ho_BzaWN0fpyKCKXfTVA8wQS9ijxuP7U'
output_name = 'Complex_yolo_yolo_v4_tiny.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1Ho_BzaWN0fpyKCKXfTVA8wQS9ijxuP7U/view?usp=sharing

shutil.move("/content/Complex_yolo_yolo_v4_tiny.pth", "/content/checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ho_BzaWN0fpyKCKXfTVA8wQS9ijxuP7U
# To: /content/Complex_yolo_yolo_v4_tiny.pth
# 100%|██████████| 23.6M/23.6M [00:00<00:00, 147MB/s]
# '/content/checkpoints/Complex_yolo_yolo_v4_tiny.pth'

# %%
# from google.colab import drive 
# drive.mount('/content/gdrive/')

# %% [markdown]
# # 10. Train YOLO v4 from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 4 --model_def config/cfg/complex_yolov4.cfg --pretrained_path checkpoints/Complex_yolo_yolo_v4.pth --save_path checkpoints/Complex_yolo_yolo_v4.pth
# Out:
# cuda
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# checkpoints/Complex_yolo_yolo_v4.pth
# Trained pytorch weight loaded!
# 579
#  33% 192/579 [02:28<04:52,  1.32it/s]
# ---- [Epoch 1/3, Batch 193/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.169018     | 0.331002     | 0.185788     |
# | loss_x     | 0.005198     | 0.005061     | 0.001660     |
# | loss_y     | 0.008755     | 0.002373     | 0.002142     |
# | loss_w     | 0.001408     | 0.006893     | 0.005868     |
# | loss_h     | 0.018736     | 0.000966     | 0.009719     |
# | loss_im    | 0.011224     | 0.009207     | 0.007335     |
# | loss_re    | 0.029928     | 0.037073     | 0.026509     |
# | loss_obj   | 0.078758     | 0.262450     | 0.125737     |
# | loss_cls   | 0.000024     | 0.001406     | 0.004372     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.988854     | 0.939935     | 0.997598     |
# | conf_noobj | 0.000271     | 0.000850     | 0.000906     |
# +------------+--------------+--------------+--------------+
# Total loss 0.6858079433441162
# ---- ETA 0:04:59.110007
#  66% 385/579 [04:52<02:29,  1.30it/s]
# ---- [Epoch 1/3, Batch 386/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.265029     | 0.506111     | 0.585712     |
# | loss_x     | 0.016264     | 0.004673     | 0.004410     |
# | loss_y     | 0.024257     | 0.006270     | 0.003578     |
# | loss_w     | 0.002310     | 0.002423     | 0.003996     |
# | loss_h     | 0.003656     | 0.003272     | 0.006911     |
# | loss_im    | 0.009418     | 0.003785     | 0.008593     |
# | loss_re    | 0.002491     | 0.002361     | 0.004788     |
# | loss_obj   | 0.204361     | 0.481075     | 0.546179     |
# | loss_cls   | 0.000506     | 0.000603     | 0.004607     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.953478     | 0.859446     | 0.839919     |
# | conf_noobj | 0.000463     | 0.001066     | 0.000689     |
# +------------+--------------+--------------+--------------+
# Total loss 1.356851577758789
# ---- ETA 0:02:26.681008
# 100% 578/579 [07:18<00:00,  1.50it/s]
# ---- [Epoch 1/3, Batch 579/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.172267     | 0.218154     | 0.229688     |
# | loss_x     | 0.014408     | 0.003277     | 0.002150     |
# | loss_y     | 0.005592     | 0.002788     | 0.002302     |
# | loss_w     | 0.006231     | 0.006166     | 0.007334     |
# | loss_h     | 0.012451     | 0.012690     | 0.016190     |
# | loss_im    | 0.012801     | 0.003252     | 0.006727     |
# | loss_re    | 0.004256     | 0.003085     | 0.002531     |
# | loss_obj   | 0.112630     | 0.184678     | 0.189423     |
# | loss_cls   | 0.000013     | 0.000077     | 0.001323     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.948171     | 0.952855     | 0.923855     |
# | conf_noobj | 0.000244     | 0.000400     | 0.000212     |
# +------------+--------------+--------------+--------------+
# Total loss 0.620109498500824
# ---- ETA 0:00:00
# 100% 579/579 [07:20<00:00,  1.32it/s]
# Current epoch loss : 1.26504 Saved at checkpoints/Complex_yolo_yolo_v4.pth
# 579
#  33% 192/579 [02:25<05:10,  1.25it/s]
# ---- [Epoch 2/3, Batch 193/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.166716     | 0.456322     | 0.361348     |
# | loss_x     | 0.007642     | 0.003764     | 0.001026     |
# | loss_y     | 0.037717     | 0.011230     | 0.005742     |
# | loss_w     | 0.003770     | 0.002292     | 0.005279     |
# | loss_h     | 0.006094     | 0.009302     | 0.017940     |
# | loss_im    | 0.001243     | 0.001383     | 0.002879     |
# | loss_re    | 0.000763     | 0.001110     | 0.001731     |
# | loss_obj   | 0.108507     | 0.425921     | 0.324675     |
# | loss_cls   | 0.000012     | 0.000056     | 0.000291     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.974403     | 0.858350     | 0.902684     |
# | conf_noobj | 0.000334     | 0.000754     | 0.000882     |
# +------------+--------------+--------------+--------------+
# Total loss 0.9843859672546387
# ---- ETA 0:19:33.792654
#  66% 385/579 [04:50<02:15,  1.43it/s]
# ---- [Epoch 2/3, Batch 386/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.219770     | 0.345205     | 0.535851     |
# | loss_x     | 0.007284     | 0.002758     | 0.005742     |
# | loss_y     | 0.020403     | 0.005213     | 0.004351     |
# | loss_w     | 0.004605     | 0.010042     | 0.011344     |
# | loss_h     | 0.007154     | 0.026068     | 0.024102     |
# | loss_im    | 0.009890     | 0.018670     | 0.020130     |
# | loss_re    | 0.008273     | 0.020552     | 0.027106     |
# | loss_obj   | 0.159272     | 0.258727     | 0.429393     |
# | loss_cls   | 0.000226     | 0.001622     | 0.007171     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.967659     | 0.930629     | 0.878902     |
# | conf_noobj | 0.000528     | 0.000782     | 0.001158     |
# +------------+--------------+--------------+--------------+
# Total loss 1.100825548171997
# ---- ETA 0:06:06.004454
# 100% 578/579 [07:15<00:00,  1.25it/s]
# ---- [Epoch 2/3, Batch 579/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.211776     | 0.422525     | 0.341199     |
# | loss_x     | 0.012155     | 0.004485     | 0.006430     |
# | loss_y     | 0.026859     | 0.009144     | 0.003716     |
# | loss_w     | 0.003035     | 0.005200     | 0.007897     |
# | loss_h     | 0.004082     | 0.011094     | 0.021124     |
# | loss_im    | 0.002971     | 0.008033     | 0.017882     |
# | loss_re    | 0.001218     | 0.003312     | 0.007095     |
# | loss_obj   | 0.159875     | 0.380069     | 0.272485     |
# | loss_cls   | 0.000102     | 0.000481     | 0.001395     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.965859     | 0.899377     | 0.927128     |
# | conf_noobj | 0.000570     | 0.001156     | 0.001107     |
# +------------+--------------+--------------+--------------+
# Total loss 0.9754999279975891
# ---- ETA 0:00:00
# 100% 579/579 [07:15<00:00,  1.33it/s]
# Current epoch loss : 0.83304 Saved at checkpoints/Complex_yolo_yolo_v4.pth
# 579
#  33% 192/579 [02:25<04:35,  1.40it/s]
# ---- [Epoch 3/3, Batch 193/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.294155     | 0.460554     | 0.433180     |
# | loss_x     | 0.009068     | 0.004205     | 0.004957     |
# | loss_y     | 0.008419     | 0.016982     | 0.011742     |
# | loss_w     | 0.005767     | 0.005195     | 0.002567     |
# | loss_h     | 0.003489     | 0.005459     | 0.005643     |
# | loss_im    | 0.008843     | 0.010482     | 0.009182     |
# | loss_re    | 0.016707     | 0.025718     | 0.021021     |
# | loss_obj   | 0.229923     | 0.389533     | 0.373231     |
# | loss_cls   | 0.000047     | 0.000538     | 0.001177     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.944760     | 0.899532     | 0.915280     |
# | conf_noobj | 0.000695     | 0.001076     | 0.001311     |
# +------------+--------------+--------------+--------------+
# Total loss 1.1878890991210938
# ---- ETA 0:34:07.130701
#  66% 385/579 [04:50<02:33,  1.26it/s]
# ---- [Epoch 3/3, Batch 386/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.157909     | 0.157158     | 0.186685     |
# | loss_x     | 0.005803     | 0.003731     | 0.002761     |
# | loss_y     | 0.022772     | 0.003938     | 0.003947     |
# | loss_w     | 0.003155     | 0.005937     | 0.003954     |
# | loss_h     | 0.003489     | 0.004402     | 0.007166     |
# | loss_im    | 0.003305     | 0.001868     | 0.003560     |
# | loss_re    | 0.004620     | 0.003031     | 0.007225     |
# | loss_obj   | 0.108888     | 0.131985     | 0.155272     |
# | loss_cls   | 0.001324     | 0.001107     | 0.001854     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.978003     | 0.964929     | 0.954184     |
# | conf_noobj | 0.000437     | 0.000552     | 0.000700     |
# +------------+--------------+--------------+--------------+
# Total loss 0.501752495765686
# ---- ETA 0:09:44.104056
# 100% 578/579 [07:13<00:00,  1.51it/s]
# ---- [Epoch 3/3, Batch 579/579] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 76           | 38           | 19           |
# | loss       | 0.327970     | 0.450150     | 0.419825     |
# | loss_x     | 0.019851     | 0.003466     | 0.010754     |
# | loss_y     | 0.031462     | 0.010608     | 0.003484     |
# | loss_w     | 0.002724     | 0.002047     | 0.005309     |
# | loss_h     | 0.012291     | 0.015843     | 0.032351     |
# | loss_im    | 0.008658     | 0.008629     | 0.010406     |
# | loss_re    | 0.034361     | 0.005486     | 0.007984     |
# | loss_obj   | 0.194641     | 0.401058     | 0.343302     |
# | loss_cls   | 0.000052     | 0.000638     | 0.002738     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.943660     | 0.884907     | 0.902005     |
# | conf_noobj | 0.000569     | 0.000994     | 0.001129     |
# +------------+--------------+--------------+--------------+
# Total loss 1.1979451179504395
# ---- ETA 0:00:00
# 100% 579/579 [07:14<00:00,  1.33it/s]
# Current epoch loss : 0.83859 Saved at checkpoints/Complex_yolo_yolo_v4.pth
#
# ---- Evaluating Model ----
# 100% 354/354 [02:15<00:00,  2.61it/s]
# Computing AP: 100% 3/3 [00:00<00:00, 135.00it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | Car        | 0.93401 |
# | 1     | Pedestrian | 0.71143 |
# | 2     | Cyclist    | 0.78192 |
# +-------+------------+---------+
# ---- mAP 0.8091191011499225

# %% [markdown]
# # 12. Train YOLO v4-tiny from Pre-trained Weights

# %%
! python train.py  --num_epochs 3 --batch_size 16 --model_def config/cfg/complex_yolov4_tiny.cfg --pretrained_path checkpoints/Complex_yolo_yolo_v4_tiny.pth --save_path checkpoints/Complex_yolo_yolo_v4_tiny.pth
# Out:
# cuda
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# checkpoints/Complex_yolo_yolo_v4_tiny.pth
# Trained pytorch weight loaded!
# 145
#  32% 47/145 [00:51<01:31,  1.07it/s]
# ---- [Epoch 1/3, Batch 48/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 2.494532     | 1.567248     |
# | loss_x     | 0.031365     | 0.028811     |
# | loss_y     | 0.022207     | 0.025034     |
# | loss_w     | 0.019735     | 0.004543     |
# | loss_h     | 0.049221     | 0.012381     |
# | loss_im    | 0.195261     | 0.139363     |
# | loss_re    | 0.323194     | 0.267229     |
# | loss_obj   | 1.639228     | 0.944207     |
# | loss_cls   | 0.081522     | 0.002563     |
# | cls_acc    | 95.12%       | 100.00%      |
# | conf_obj   | 0.687789     | 0.835581     |
# | conf_noobj | 0.003105     | 0.001864     |
# +------------+--------------+--------------+
# Total loss 4.061779975891113
# ---- ETA 0:01:45.847479
#  66% 95/145 [01:35<00:46,  1.09it/s]
# ---- [Epoch 1/3, Batch 96/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 2.184836     | 1.605945     |
# | loss_x     | 0.027273     | 0.026900     |
# | loss_y     | 0.020496     | 0.027123     |
# | loss_w     | 0.011214     | 0.006416     |
# | loss_h     | 0.026401     | 0.013468     |
# | loss_im    | 0.087650     | 0.063200     |
# | loss_re    | 0.281921     | 0.300594     |
# | loss_obj   | 1.530737     | 1.036519     |
# | loss_cls   | 0.086607     | 0.005017     |
# | cls_acc    | 93.94%       | 100.00%      |
# | conf_obj   | 0.611580     | 0.769912     |
# | conf_noobj | 0.002895     | 0.001955     |
# +------------+--------------+--------------+
# Total loss 3.7907803058624268
# ---- ETA 0:00:49.437003
#  99% 143/145 [02:17<00:00,  2.04it/s]
# ---- [Epoch 1/3, Batch 144/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 1.714922     | 1.015382     |
# | loss_x     | 0.011825     | 0.019690     |
# | loss_y     | 0.018955     | 0.016927     |
# | loss_w     | 0.013580     | 0.003541     |
# | loss_h     | 0.022938     | 0.011017     |
# | loss_im    | 0.051961     | 0.039484     |
# | loss_re    | 0.199365     | 0.213892     |
# | loss_obj   | 1.220870     | 0.639987     |
# | loss_cls   | 0.074016     | 0.000738     |
# | cls_acc    | 97.18%       | 100.00%      |
# | conf_obj   | 0.645621     | 0.818962     |
# | conf_noobj | 0.002958     | 0.001720     |
# +------------+--------------+--------------+
# Total loss 2.730304718017578
# ---- ETA 0:00:00.957782
# 100% 145/145 [02:18<00:00,  1.05it/s]
# Current epoch loss : 4.57370 Saved at checkpoints/Complex_yolo_yolo_v4_tiny.pth
# 145
#  32% 47/145 [00:52<01:39,  1.02s/it]
# ---- [Epoch 2/3, Batch 48/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 1.794655     | 1.119251     |
# | loss_x     | 0.009931     | 0.013872     |
# | loss_y     | 0.013734     | 0.012394     |
# | loss_w     | 0.011875     | 0.005516     |
# | loss_h     | 0.042670     | 0.011256     |
# | loss_im    | 0.069762     | 0.054931     |
# | loss_re    | 0.299597     | 0.246194     |
# | loss_obj   | 1.144218     | 0.658297     |
# | loss_cls   | 0.077320     | 0.001532     |
# | cls_acc    | 93.10%       | 100.00%      |
# | conf_obj   | 0.718093     | 0.845696     |
# | conf_noobj | 0.002953     | 0.002039     |
# +------------+--------------+--------------+
# Total loss 2.913905620574951
# ---- ETA 0:06:28.067854
#  66% 95/145 [01:40<00:44,  1.12it/s]
# ---- [Epoch 2/3, Batch 96/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 2.345485     | 1.437512     |
# | loss_x     | 0.018301     | 0.017971     |
# | loss_y     | 0.021017     | 0.028802     |
# | loss_w     | 0.009833     | 0.005547     |
# | loss_h     | 0.031788     | 0.017451     |
# | loss_im    | 0.126792     | 0.120594     |
# | loss_re    | 0.280087     | 0.303840     |
# | loss_obj   | 1.638718     | 0.796106     |
# | loss_cls   | 0.104638     | 0.025307     |
# | cls_acc    | 94.64%       | 98.25%       |
# | conf_obj   | 0.600913     | 0.783167     |
# | conf_noobj | 0.002796     | 0.001587     |
# +------------+--------------+--------------+
# Total loss 3.782996654510498
# ---- ETA 0:02:02.491487
#  99% 143/145 [02:25<00:01,  1.94it/s]
# ---- [Epoch 2/3, Batch 144/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 1.355241     | 0.890833     |
# | loss_x     | 0.014426     | 0.017669     |
# | loss_y     | 0.011136     | 0.019285     |
# | loss_w     | 0.005383     | 0.004851     |
# | loss_h     | 0.020080     | 0.010375     |
# | loss_im    | 0.042362     | 0.044420     |
# | loss_re    | 0.226599     | 0.232433     |
# | loss_obj   | 0.950010     | 0.482247     |
# | loss_cls   | 0.009761     | 0.000590     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.748369     | 0.875159     |
# | conf_noobj | 0.002862     | 0.001501     |
# +------------+--------------+--------------+
# Total loss 2.2460741996765137
# ---- ETA 0:00:01.977127
# 100% 145/145 [02:26<00:00,  1.01s/it]
# Current epoch loss : 3.33101 Saved at checkpoints/Complex_yolo_yolo_v4_tiny.pth
# 145
#  32% 47/145 [00:52<01:39,  1.01s/it]
# ---- [Epoch 3/3, Batch 48/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 1.374601     | 0.994258     |
# | loss_x     | 0.015600     | 0.027613     |
# | loss_y     | 0.021447     | 0.019817     |
# | loss_w     | 0.005252     | 0.005804     |
# | loss_h     | 0.025748     | 0.017016     |
# | loss_im    | 0.117604     | 0.114892     |
# | loss_re    | 0.202882     | 0.185783     |
# | loss_obj   | 0.878630     | 0.530550     |
# | loss_cls   | 0.017881     | 0.001535     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.737026     | 0.845109     |
# | conf_noobj | 0.002481     | 0.001472     |
# +------------+--------------+--------------+
# Total loss 2.36885929107666
# ---- ETA 0:11:24.647128
#  66% 95/145 [01:39<00:50,  1.00s/it]
# ---- [Epoch 3/3, Batch 96/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 2.257787     | 1.497665     |
# | loss_x     | 0.018639     | 0.034195     |
# | loss_y     | 0.021341     | 0.028805     |
# | loss_w     | 0.012789     | 0.006180     |
# | loss_h     | 0.025067     | 0.014219     |
# | loss_im    | 0.193062     | 0.194190     |
# | loss_re    | 0.230643     | 0.214218     |
# | loss_obj   | 1.604764     | 0.848205     |
# | loss_cls   | 0.036566     | 0.054415     |
# | cls_acc    | 98.89%       | 96.81%       |
# | conf_obj   | 0.585104     | 0.779259     |
# | conf_noobj | 0.003807     | 0.002268     |
# +------------+--------------+--------------+
# Total loss 3.7554523944854736
# ---- ETA 0:03:17.113013
#  99% 143/145 [02:24<00:01,  1.96it/s]
# ---- [Epoch 3/3, Batch 144/145] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 2.214946     | 1.721864     |
# | loss_x     | 0.022148     | 0.018882     |
# | loss_y     | 0.028452     | 0.021195     |
# | loss_w     | 0.015060     | 0.005765     |
# | loss_h     | 0.038472     | 0.021942     |
# | loss_im    | 0.208018     | 0.189442     |
# | loss_re    | 0.206928     | 0.223692     |
# | loss_obj   | 1.423432     | 0.989556     |
# | loss_cls   | 0.148173     | 0.121846     |
# | cls_acc    | 94.29%       | 94.37%       |
# | conf_obj   | 0.643701     | 0.791728     |
# | conf_noobj | 0.002878     | 0.002042     |
# +------------+--------------+--------------+
# Total loss 3.93681001663208
# ---- ETA 0:00:02.989669
# 100% 145/145 [02:25<00:00,  1.01s/it]
# Current epoch loss : 3.17200 Saved at checkpoints/Complex_yolo_yolo_v4_tiny.pth
#
# ---- Evaluating Model ----
# 100% 89/89 [01:34<00:00,  1.06s/it]
# Computing AP: 100% 3/3 [00:00<00:00, 135.02it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | Car        | 0.98834 |
# | 1     | Pedestrian | 0.38143 |
# | 2     | Cyclist    | 0.58004 |
# +-------+------------+---------+
# ---- mAP 0.6499379373077158
